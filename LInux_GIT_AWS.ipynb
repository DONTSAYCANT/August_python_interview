# %%
"""
Program2:

Get a number from user 
"""
a = int(input("give your number"))
for i in range(a):
    for temp in range(i+1):
        print(a-temp,end=" ")
    print()


a =[]
b =[]
z = []
c = int(input("give your list length1"))
d = int(input("give your list length2"))
for i in range(c):
    temp = int(input("give your list1"))
    a.append(temp)
    print(a)
for j in range(d):
    temp1 = int(input("give your list2"))
    b.append(temp1)
    print(b)
for k in (a):
    for l in (b):
        if k==l:
            z.append(i)
print("the value",z)
            
    

a =[]
r =[]
v =[]
c = int(input("give your list length1"))
for i in range(c):
    temp = int(input("give your list1"))
    a.append(temp)
    print(a)
b = len(a)
for j in range(0,b):
    d=0
    for k in range(2,a[i]):
        if a[i]%k==0:
            d =1
            break
    if d==0:
        print("its a prime number")
        r.append(i)
        print(r)
    else:
        print("its not a prinme number")
        v.append(i)
        print(v)

"""
Get two strings from user 

computer ==> find ascii value for each char ==> add everything
Information ==>  find ascii value for each char  ==> add everything

True Otherwise False"""


a = input("enter your string")
b = input("enter your string")
c =[]
d =[]
for i in (a):
    print(ord (i))
    c.append(i)
    print(c)
for j in (b):
    print(ord(j))
    d.append(i)
    print(d)
    if sum(c)==sum(d):
        print("True")
    else:
        print("False")

# %%
#mark 5

a = int(input("give your number"))
for i in range(a):
    for temp in range(i+1):
        print(a-temp,end=" ")
    print()
# Out:
# give your number9
# 9
# 9 8
# 9 8 7
# 9 8 7 6
# 9 8 7 6 5
# 9 8 7 6 5 4
# 9 8 7 6 5 4 3
# 9 8 7 6 5 4 3 2
# 9 8 7 6 5 4 3 2 1

# %%
#mark 2

a =[]
b =[]
z = []
c = int(input("give your list length1"))
d = int(input("give your list length2"))
for i in range(c):
    temp = int(input("give your list1"))
    a.append(temp)
    print(a)
for j in range(d):
    temp1 = int(input("give your list2"))
    b.append(temp1)
    print(b)
for k in (a):
    for l in (b):
        if k==l:
            z.append(i)
print("the value",z)
# Out:
# give your list length15
# give your list length24
# give your list11
# [1]
# give your list12
# [1, 2]
# give your list11
# [1, 2, 1]
# give your list12
# [1, 2, 1, 2]
# give your list13
# [1, 2, 1, 2, 3]
# give your list21
# [1]
# give your list22
# [1, 2]
# give your list23
# [1, 2, 3]
# give your list24
# [1, 2, 3, 4]
# the value [4, 4, 4, 4, 4]

# %%
#mark 1

a =[]
r =[]
v =[]
c = int(input("give your list length1"))
for i in range(c):
    temp = int(input("give your list1"))
    a.append(temp)
    print(a)
b = len(a)
for j in range(0,b):
    d=0
    for k in range(2,a[i]):
        if a[i]%k==0:
            d =1
            break
    if d==0:
        print("its a prime number")
        r.append(i)
        print(r)
    else:
        print("its not a prinme number")
        v.append(i)
        print(v)
# Out:
# give your list length13
# give your list15
# [5]
# give your list110
# [5, 10]
# give your list115
# [5, 10, 15]
# its not a prinme number
# [2]
# its not a prinme number
# [2, 2]
# its not a prinme number
# [2, 2, 2]

# %%
#mark 1

a = input("enter your string")
b = input("enter your string")
c =[]
d =[]
for i in (a):
    print(ord (i))
    c.append(i)
    print(c)
for j in (b):
    print(ord(j))
    d.append(i)
    print(d)
    if sum(c)==sum(d):
        print("True")
    else:
        print("False")
# Out:
# enter your stringpython
# enter your stringgroovy
# 112
# ['p']
# 121
# ['p', 'y']
# 116
# ['p', 'y', 't']
# 104
# ['p', 'y', 't', 'h']
# 111
# ['p', 'y', 't', 'h', 'o']
# 110
# ['p', 'y', 't', 'h', 'o', 'n']
# 103
# ['n']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0689bff6207e> in <module>
#      11     d.append(i)
#      12     print(d)
# ---> 13     if sum(c)==sum(d):
#      14         print("True")
#      15     else:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#prime

#3 = [1,3]
#4 = [1,2,4]
#5 = [1,5]
#6 = [1,2,3,6]
#12 = [1,2,3,4,6,12]

#17  == [1,17]


val = 12
multiples = []

for i in range(1,val+1):
    if val % i == 0:
        multiples.append(i)
print(multiples)




#non prime
# Out:
# [1, 2, 3, 4, 6, 12]

# %%
while True:
    print("please select any one operation 1. add 2. sub 3. multiply")
    input_int = int(input())
    if input_int == 1:
        print("add operation")
    elif input_int == 2:
        print("sub operation")
    elif input_int == 3:
        print("multiply operation")
    else:
        print("please selct valid option")
        
    program_continue = input("Do you want to continue the operation Y/N")
    
    if program_continue == "N":
        break
# Out:
# please select any one operation 1. add 2. sub 3. multiply
# 1
# add operation
# Do you want to continue the operation Y/NY
# please select any one operation 1. add 2. sub 3. multiply
# 2
# sub operation
# Do you want to continue the operation Y/N3
# please select any one operation 1. add 2. sub 3. multiply
# 4
# please selct valid option
# Do you want to continue the operation Y/NN

# %%
#array

#Data structure to store multiple values 
#Homogenous DS
#val = np.array([1,2,3,4,"hello"])


#List

#Data structure to store multiple values 
#Heterogenous DS
#a = [1,2,3.3,True]

# %%
a = [1,2,3.3,True]

# %%
import numpy as np

val = np.array([1,2,3,4,"hello"])

print(val)
print(type(val))
# Out:
# ['1' '2' '3' '4' 'hello']
# <class 'numpy.ndarray'>

# %%
#Linux / git

#Linux ?

#Operating System
#Open source / Free
#Adaptable
#Less weight
#Developer friendely
#terminal


#Windows 

#GUI good ==> User friendly 
#Power shell
#windows paid 



#Virtualization

#one OS inside another OS
#resource sharing

#VMware 
#oracle virtual box

#Hypervisor


#Cloud : 

#Account creation
#https://portal.aws.amazon.com/gp/aws/developer/registration/index.html?refid=ps_a134p000003yhmgaaq&trkcampaign=acq_paid_search_brand
    

#EC2 / VPC / S3 / ROUTE53 / DNS / RDS / IAM / availabilty Zones /AMI / 
#EC2 instance creation
#Machine login
#S3 store file


#Networking Terms:

#public ip / private ip
#command prompt
#terminal
#powershell
#DNS
#http/https
#Firewall
#ISO/OSI layers layers 


Platform as a service ===>  AMI

Infrastruture as a service ==> AWS/vmware/Google cloud

Software as a service  ===> gmail /


#Charge as per use

#https://www.edureka.co/blog/linux-commands/

#50 commands 


25-Dec :
    
AWS account creation
AWS Ec2 login
linux machine : #50 linux commands
